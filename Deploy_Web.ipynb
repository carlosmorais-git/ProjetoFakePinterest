# %% [markdown]
# ### Deploy - Conceitos

# %% [markdown]
# ### 1° Criar uma arquivo PROCFILE sem extensao e adicione nele:
#
# "web: gunicorn main:app"
#
# - Esse será o intermediario do meu projeto e o servidor isso dirar qual arquivo terar que executar
#
# pip install gunicorn
#
# ### 2° Execute pip freeze > requirements.txt no terminal
#
# - Esse pip freeze lista todas as bibliotecas instaladas no nosso ambiente
# - Sera diterecionada sua saida para o arquivo requirements.txt para controle de versões
#
# ### 3° Criar um novo repositorio no git
#
# ![image.png](attachment:image.png)
#
# ### 4° Passando só essas pastas para o repositorio
#
# ![image-2.png](attachment:image-2.png)
#
# - Pasta do projeto (Templates,init..)
# - Arquivo main.py
# - Procfile
# - requirements.txt (ele contem todas as bibliotecas para o funcionamento do site)
#
# ### 5° Coloca seu repositorio em um servidor Usarei Railway
#
# Primeiro cria um banco de dados
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ### 6° Importa o projeto via Git
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ### 7°
